# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
accident_data = pd.read_csv("accident.csv")
accident_data
# Out:
#        STATE  ST_CASE  VE_TOTAL  VE_FORMS  PVH_INVL  PEDS  PERNOTMVIT  \
# 0          1    10001         1         1         0     0           0
# 1          1    10002         1         1         0     0           0
# 2          1    10003         1         1         0     0           0
# 3          1    10004         1         1         0     0           0
# 4          1    10005         2         2         0     0           0
# 5          1    10006         1         1         0     0           0
# 6          1    10007         1         1         0     0           0
# 7          1    10008         1         1         0     1           1
# 8          1    10009         1         1         0     0           0
# 9          1    10010         2         2         0     0           0
# 10         1    10011         2         2         0     0           0
# 11         1    10012         3         3         0     0           0
# ...

# %%
accident_data.columns
# Out:
# Index(['STATE', 'ST_CASE', 'VE_TOTAL', 'VE_FORMS', 'PVH_INVL', 'PEDS',
#        'PERNOTMVIT', 'PERMVIT', 'PERSONS', 'COUNTY', 'CITY', 'DAY', 'MONTH',
#        'YEAR', 'DAY_WEEK', 'HOUR', 'MINUTE', 'NHS', 'RUR_URB', 'FUNC_SYS',
#        'RD_OWNER', 'ROUTE', 'TWAY_ID', 'TWAY_ID2', 'MILEPT', 'LATITUDE',
#        'LONGITUD', 'SP_JUR', 'HARM_EV', 'MAN_COLL', 'RELJCT1', 'RELJCT2',
#        'TYP_INT', 'WRK_ZONE', 'REL_ROAD', 'LGT_COND', 'WEATHER1', 'WEATHER2',
#        'WEATHER', 'SCH_BUS', 'RAIL', 'NOT_HOUR', 'NOT_MIN', 'ARR_HOUR',
#        'ARR_MIN', 'HOSP_HR', 'HOSP_MN', 'CF1', 'CF2', 'CF3', 'FATALS',
#        'DRUNK_DR'],
#       dtype='object')

# %%
State_Deaths = accident_data.loc[:, ["STATE","ARR_MIN","FATALS"]]
State_Deaths


State_Deaths = State_Deaths.set_index("STATE")

State_Deaths.head()
# Out:
#        ARR_MIN  FATALS
# STATE
# 1           58       1
# 1           20       1
# 1           45       1
# 1           15       1
# 1           16       1

# %%
CO_Deaths = State_Deaths.loc[6,["ARR_MIN","FATALS"]]
CO_Deaths
# Out:
#        ARR_MIN  FATALS
# STATE
# 6           99       1
# 6           99       2
# 6           99       1
# 6           99       1
# 6           99       1
# 6           99       1
# 6           99       1
# 6           99       2
# 6           99       1
# 6           99       1
# 6           99       1
# 6           99       1
# 6           99       1
# 6           99       1
# 6           99       1
# 6           99       1
# 6           99       1
# 6           99       1
# 6           99       1
# 6           99       1
# 6           99       1
# 6           99       1
# 6           99       1
# 6           99       2
# 6           99       2
# 6           99       1
# 6           99       1
# 6           99       1
# 6           99       1
# 6           99       1
# ...        ...     ...
# 6           99       1
# 6           99       4
# 6           99       1
# 6           99       1
# 6           99       1
# 6           99       1
# 6           99       1
# ...

# %%
ARR_MIN = CO_Deaths["ARR_MIN"].value_counts()
FATALS = CO_Deaths["FATALS"].value_counts()

# %%
CO_Deaths = ARR_MIN.add(FATALS, fill_value=0)
CO_Deaths
# Out:
# 1     2912.0
# 2      174.0
# 3       25.0
# 4       10.0
# 5        3.0
# 6        2.0
# 10       1.0
# 11       1.0
# 14       1.0
# 15       1.0
# 19       1.0
# 27       1.0
# 31       1.0
# 35       1.0
# 39       2.0
# 40       1.0
# 50       2.0
# 53       1.0
# 54       1.0
# 57       1.0
# 88       2.0
# 97       1.0
# 99    3101.0
# dtype: float64

# %%
CO_Deaths.plot(kind="bar")
plt.title("Arrival Time of EMS vs Fatalities")
plt.ylabel("Deaths")
plt.xlabel("Arrival Time of EMS in Min")
plt.show()

# %%
plt.savefig('ArrivalTime.png')
