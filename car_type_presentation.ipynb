# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### Using MatplotLib to Chart a DataFrame

# %%
# Load in csv
all_df = pd.read_csv("Resources/person.csv")
all_df.head()
all_df.columns
# Out:
# Index(['STATE', 'ST_CASE', 'VE_FORMS', 'VEH_NO', 'PER_NO', 'STR_VEH', 'COUNTY',
#        'DAY', 'MONTH', 'HOUR', 'MINUTE', 'RUR_URB', 'FUNC_SYS', 'HARM_EV',
#        'MAN_COLL', 'SCH_BUS', 'MAKE', 'MAK_MOD', 'BODY_TYP', 'MOD_YEAR',
#        'TOW_VEH', 'SPEC_USE', 'EMER_USE', 'ROLLOVER', 'IMPACT1', 'FIRE_EXP',
#        'AGE', 'SEX', 'PER_TYP', 'INJ_SEV', 'SEAT_POS', 'REST_USE', 'REST_MIS',
#        'AIR_BAG', 'EJECTION', 'EJ_PATH', 'EXTRICAT', 'DRINKING', 'ALC_DET',
#        'ALC_STATUS', 'ATST_TYP', 'ALC_RES', 'DRUGS', 'DRUG_DET', 'DSTATUS',
#        'DRUGTST1', 'DRUGTST2', 'DRUGTST3', 'DRUGRES1', 'DRUGRES2', 'DRUGRES3',
#        'HOSPITAL', 'DOA', 'DEATH_DA', 'DEATH_MO', 'DEATH_YR', 'DEATH_HR',
#        'DEATH_MN', 'DEATH_TM', 'LAG_HRS', 'LAG_MINS', 'P_SF1', 'P_SF2',
#        'P_SF3', 'WORK_INJ', 'HISPANIC', 'RACE', 'LOCATION'],
#       dtype='object')

# %%
def_df = pd.read_csv("Resources/body_type.csv")
def_df.head()
# all_df.columns
# Out:
#    BODY_TYPE                    Definition
# 0          1                   Convertible
# 1          2  2-Door Sedan, Hardtop, Coupe
# 2          3       3-Door/2-Door Hatchback
# 3          4        (4-Door Sedan, Hardtop
# 4          5       5-Door/4-Door Hatchback

# %%
# Get body_type data
body_type_data = all_df["BODY_TYP"].value_counts()
body_type_data.sort_values(ascending=False)
first_40_types = body_type_data.nlargest(40)

first_40_types.values

body_type_df = pd.DataFrame({'BODY_TYPE' : first_40_types.index, 
    'accident_total' : first_40_types.values
})

body_type_df

final_data = pd.merge(body_type_df, def_df, on = 'BODY_TYPE')
final_data
# Out:
#     BODY_TYPE  accident_total  \
# 0         4.0           22047
# 1        31.0           10369
# 2        14.0            9117
# 3        80.0            5339
# 4        15.0            3790
# 5         2.0            3393
# 6        66.0            3221
# 7        20.0            3149
# 8        30.0            2462
# 9         6.0            2393
# 10       21.0            1187
# 11        5.0             967
# 12        3.0             831
# 13       99.0             785
# 14       63.0             651
# 15       16.0             629
# 16        1.0             509
# 17       90.0             449
# 18       50.0             370
# 19       52.0             281
# 20       62.0             281
# 21       61.0             239
# 22        9.0             191
# 23       67.0             186
# 24       40.0             175
# 25       81.0             157
# 26       51.0             136
# 27       88.0             111
# 28       92.0             111
# 29       97.0              78
# 30       29.0              69
# 31       64.0              63
# 32       58.0              62
# 33       78.0              60
# 34       59.0              58
# 35       73.0              57
# 36       83.0              53
# 37       22.0              51
# 38       55.0              46
# 39       49.0              37
#
#                                            Definition
# 0                              (4-Door Sedan, Hardtop
# 1                                     Standard Pickup
# 2                                     Compact Utility
# 3                                          Motorcycle
# 4                                       Large Utility
# 5                        2-Door Sedan, Hardtop, Coupe
# 6   Truck-Tractor [Cab only or with any number of ...
# 7                                             Minivan
# 8                                      Compact Pickup
# 9       Station wagon [excluding van and truck based]
# 10                                          Large Van
# 11                            5-Door/4-Door Hatchback
# 12                            3-Door/2-Door Hatchback
# 13                                  Unknown Body Type
# 14          Single-Unit Straight Truck or Cab-chassis
# 15                              Utility Station Wagon
# 16                                        Convertible
# 17                        ATV/ATC [All-Terrain Cycle]
# 18                                         School Bus
# 19                             Transit Bus [City Bus]
# 20                                                NaN
# 21          Single-Unit Straight Truck or Cab-chassis
# 22                   Other or Unknown automobile type
# 23           Medium/Heavy Pick-up [>10,000 lbs. GVWR]
# 24  Cab Chassis Based [includes rescue vehicles, l...
# 25                          Moped [motorized bicycle]
# 26                        Cross Country/Intercity Bus
# 27  Other Motored Cycle [mini-bike, motor scooter,...
# 28                   Farm Equipment Other Than Trucks
# 29                                 Other Vehicle Type
# 30                                   Unknown Van Type
# 31  Single-Unit Straight Truck or Cab-chassis [GVW...
# 32                                     Other Bus Type
# 33                    Unknown Medium/Heavy Truck Type
# 34                                   Unknown Bus Type
# 35            Camper or Motor Home, unknown truck typ
# 36                      Off-road Motorcycle [2-wheel]
# 37     Step Van or Walk-In Van [< = 10,000 lbs. GVWR]
# 38                    Van-Based Bus GVWR > 10,000 lbs
# 39  Unknown Light Vehicle Type [automobile, utilit...

# %%
# Configure plot and ticks
first_40_types.plot(kind="bar", facecolor="red")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# x_axis = np.arange(0, 40)
# tick_locations = []
# for x in x_axis:
#     tick_locations.append(x)

plt.title("Body Types Accidents in the nation")
plt.xlabel("Body Type")
plt.ylabel("Number of Accedents")

# plt.xlim(-0.75, len(gyms)-.25)
# plt.ylim(0, max(members) + 5)

plt.bar(final_data['Definition'], final_data['accident_total'] , facecolor="red", alpha=0.75, align="center")
# plt.xticks(tick_locations, gyms)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-29ce4030699f> in <module>()
#      11 # plt.ylim(0, max(members) + 5)
#      12
# ---> 13 plt.bar(final_data['Definition'], final_data['accident_total'] , facecolor="red", alpha=0.75, align="center")
#      14 # plt.xticks(tick_locations, gyms)
#      15 plt.show()
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in bar(*args, **kwargs)
#    2768                       mplDeprecation)
#    2769     try:
# -> 2770         ret = ax.bar(*args, **kwargs)
#    2771     finally:
#    2772         ax._hold = washold
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in bar(self, *args, **kwargs)
#    2218         # subtracted uniformly
#    2219         if self.xaxis is not None:
# -> 2220             x = self.convert_xunits(x)
#    2221             width = self.convert_xunits(width)
#    2222             if xerr is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/artist.py in convert_xunits(self, x)
#     189         if ax is None or ax.xaxis is None:
#     190             return x
# --> 191         return ax.xaxis.convert_units(x)
#     192
#     193     def convert_yunits(self, y):
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axis.py in convert_units(self, x)
#    1524             return x
#    1525
# -> 1526         ret = self.converter.convert(x, self.units, self)
#    1527         return ret
#    1528
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/category.py in convert(value, unit, axis)
#      63
#      64         # force an update so it also does type checking
# ---> 65         unit.update(values)
#      66
#      67         str2idx = np.vectorize(unit._mapping.__getitem__,
#
# AttributeError: 'NoneType' object has no attribute 'update'
