# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
accident_data = pd.read_csv("accident.csv")
accident_data
# Out:
#        STATE  ST_CASE  VE_TOTAL  VE_FORMS  PVH_INVL  PEDS  PERNOTMVIT  \
# 0          1    10001         1         1         0     0           0
# 1          1    10002         1         1         0     0           0
# 2          1    10003         1         1         0     0           0
# 3          1    10004         1         1         0     0           0
# 4          1    10005         2         2         0     0           0
# 5          1    10006         1         1         0     0           0
# 6          1    10007         1         1         0     0           0
# 7          1    10008         1         1         0     1           1
# 8          1    10009         1         1         0     0           0
# 9          1    10010         2         2         0     0           0
# 10         1    10011         2         2         0     0           0
# 11         1    10012         3         3         0     0           0
# ...

# %%
accident_data.columns
# Out:
# Index(['STATE', 'ST_CASE', 'VE_TOTAL', 'VE_FORMS', 'PVH_INVL', 'PEDS',
#        'PERNOTMVIT', 'PERMVIT', 'PERSONS', 'COUNTY', 'CITY', 'DAY', 'MONTH',
#        'YEAR', 'DAY_WEEK', 'HOUR', 'MINUTE', 'NHS', 'RUR_URB', 'FUNC_SYS',
#        'RD_OWNER', 'ROUTE', 'TWAY_ID', 'TWAY_ID2', 'MILEPT', 'LATITUDE',
#        'LONGITUD', 'SP_JUR', 'HARM_EV', 'MAN_COLL', 'RELJCT1', 'RELJCT2',
#        'TYP_INT', 'WRK_ZONE', 'REL_ROAD', 'LGT_COND', 'WEATHER1', 'WEATHER2',
#        'WEATHER', 'SCH_BUS', 'RAIL', 'NOT_HOUR', 'NOT_MIN', 'ARR_HOUR',
#        'ARR_MIN', 'HOSP_HR', 'HOSP_MN', 'CF1', 'CF2', 'CF3', 'FATALS',
#        'DRUNK_DR'],
#       dtype='object')

# %%
State_Deaths = accident_data.loc[:, ["STATE", "HARM_EV", "FATALS"]]
State_Deaths = State_Deaths.set_index("STATE")

State_Deaths.head()
# Out:
#        HARM_EV  FATALS
# STATE
# 1           35       1
# 1           34       1
# 1           42       1
# 1           53       1
# 1           12       1

# %%
CO_Deaths = State_Deaths.loc[6,["HARM_EV", "FATALS"]]

CO_Deaths
# Out:
#        HARM_EV  FATALS
# STATE
# 6           24       1
# 6           12       2
# 6            8       1
# 6           12       1
# 6            8       1
# 6           43       1
# 6           12       1
# 6            1       2
# 6           24       1
# 6            8       1
# 6           12       1
# 6            8       1
# 6            8       1
# 6            8       1
# 6           12       1
# 6            8       1
# 6            8       1
# 6           15       1
# 6            8       1
# 6           12       1
# 6           30       1
# 6            1       1
# 6            8       1
# 6           12       2
# 6           42       2
# 6           12       1
# 6           17       1
# 6           52       1
# 6            1       1
# 6           12       1
# ...        ...     ...
# 6           12       1
# 6           12       4
# 6           39       1
# 6            8       1
# 6            9       1
# 6            8       1
# 6            8       1
# ...

# %%
top_causes = CO_Deaths.sort_values(["HARM_EV"], ascending=False)
top_causes = top_causes.drop_duplicates()
top_causes.head(5)
# Out:
#        HARM_EV  FATALS
# STATE
# 6           73       1
# 6           72       1
# 6           59       1
# 6           59       2
# 6           58       1

# %%
top_causes.plt.bar(x_axis, HARM_EV, color='r', alpha=0.5, align="center")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-23d0b51a758c> in <module>()
#       1
# ----> 2 top_causes.plt.bar(x_axis, HARM_EV, color='r', alpha=0.5, align="center")
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'plt'

# %%
HARM_EV_data = top_causes["HARM_EV"].value_counts()
HARM_EV_data
FATALS_data = top_causes["FATALS"].value_counts()
FATALS_data
# Out:
# 1    42
# 2    24
# 3     5
# 4     2
# 5     1
# Name: FATALS, dtype: int64
